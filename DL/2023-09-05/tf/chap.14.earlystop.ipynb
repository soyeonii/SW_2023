# %%
from tensorflow.keras import models, layers
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import os

# %%
df = pd.read_csv('data/wine.csv', header=None)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
model = models.Sequential()
model.add(layers.Dense(30, input_dim=12, activation='relu'))
model.add(layers.Dense(12, activation='relu'))
model.add(layers.Dense(8, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=20)  # val_loss의 값을 확인해 연속적으로 20번 이상 안 줄어들면 모델 학습 강제 중지
modelpath = 'model/wine_model.hdf5'
checkpoint = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=0, save_best_only=True)

# %%
history = model.fit(X_train, y_train, epochs=2000, batch_size=500, validation_split=0.25, verbose=1, callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/2000
# 8/8 [==============================] - 1s 40ms/step - loss: 4.9619 - accuracy: 0.2487 - val_loss: 2.6480 - val_accuracy: 0.2515
# Epoch 2/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 2.2194 - accuracy: 0.2474 - val_loss: 1.6819 - val_accuracy: 0.2431
# Epoch 3/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.4987 - accuracy: 0.2338 - val_loss: 1.2588 - val_accuracy: 0.2246
# Epoch 4/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1263 - accuracy: 0.1909 - val_loss: 0.9899 - val_accuracy: 0.1838
# Epoch 5/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9168 - accuracy: 0.1483 - val_loss: 0.8328 - val_accuracy: 0.1608
# Epoch 6/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.7907 - accuracy: 0.2004 - val_loss: 0.7390 - val_accuracy: 0.3346
# Epoch 7/2000
# ...

# %%
score = model.evaluate(X_test, y_test)
print('Test Accuracy: %.4f' % score[1])
# Out:
# 41/41 [==============================] - 0s 1ms/step - loss: 0.0509 - accuracy: 0.9869
# Test Accuracy: 0.9869
